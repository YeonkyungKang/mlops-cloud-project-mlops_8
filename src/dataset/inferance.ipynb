# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..', '..', 'src')))

# %%
import pandas as pd

from preprocess import load_data
from util.util_function import SEED, ROOT_PATH

# %%
data_path = '/'.join(os.getcwd().split('\\')[:-2])
output_path = f"{data_path}/dataset/preprocessed_weather_20250529.csv"
df = load_data(output_path)

# %%
df
# Out:
#         Spot_id       YMD  STN_ID       LAT        LON    target  \
# 0          6001  20230401     408  37.58463  127.06036  0.640000
# 1          6001  20230401     414  37.61172  126.99944  0.527893
# 2          6001  20230401     424  37.63801  127.00981  0.574605
# 3          6001  20230402     408  37.58463  127.06036  0.574605
# 4          6001  20230402     414  37.61172  126.99944  0.443813
# ...         ...       ...     ...       ...        ...       ...
# 317854    42804  20250525     413  37.53344  127.08601  0.434471
# 317855    42804  20250525     569  37.58224  127.15698  0.481182
# 317856    42804  20250526     402  37.55556  127.14498  0.686712
# 317857    42804  20250526     413  37.53344  127.08601  0.789477
# 317858    42804  20250526     569  37.58224  127.15698  0.677369
#
#         Sum_rainfall  Max_rainfall_1H  Max_rainfall_1H_occur_time  \
# 0             -0.563         -0.53376                         0.0
# ...

# %%
most_recent_date = df['YMD'].max()
display(most_recent_date)
count_of_most_recent_data = (df['YMD'] == most_recent_date).sum()
count_of_most_recent_data
# Out:
# np.int64(20250526)
# np.int64(405)

# %%
most_recent_date = df['YMD'].max()
display(most_recent_date - 1)
count_of_most_recent_data = (df['YMD'] == (most_recent_date - 1)).sum()
count_of_most_recent_data
# Out:
# np.int64(20250525)
# np.int64(405)

# %%
df = df[df['YMD'] != most_recent_date]

# %%
df
# Out:
#         Spot_id       YMD  STN_ID       LAT        LON    target  \
# 0          6001  20230401     408  37.58463  127.06036  0.640000
# 1          6001  20230401     414  37.61172  126.99944  0.527893
# 2          6001  20230401     424  37.63801  127.00981  0.574605
# 3          6001  20230402     408  37.58463  127.06036  0.574605
# 4          6001  20230402     414  37.61172  126.99944  0.443813
# ...         ...       ...     ...       ...        ...       ...
# 317851    42804  20250524     413  37.53344  127.08601 -0.032643
# 317852    42804  20250524     569  37.58224  127.15698 -0.060669
# 317853    42804  20250525     402  37.55556  127.14498  0.387759
# 317854    42804  20250525     413  37.53344  127.08601  0.434471
# 317855    42804  20250525     569  37.58224  127.15698  0.481182
#
#         Sum_rainfall  Max_rainfall_1H  Max_rainfall_1H_occur_time  \
# 0          -0.563000        -0.533760                         0.0
# ...

# %%
inferance_df = df[df['YMD'] == df['YMD'].max()]
inferance_df
# Out:
#         Spot_id       YMD  STN_ID       LAT        LON    target  \
# 2355       6001  20250525     408  37.58463  127.06036  0.434471
# 2356       6001  20250525     414  37.61134  126.99981  0.266310
# 2357       6001  20250525     424  37.63801  127.00981  0.359732
# 4716       6002  20250525     108  37.57142  126.96580  0.341048
# 4717       6002  20250525     419  37.55236  126.98736  0.369075
# ...         ...       ...     ...       ...        ...       ...
# 315498    42803  20250525     413  37.53344  127.08601  0.434471
# 315499    42803  20250525     421  37.54721  127.03885  0.397102
# 317853    42804  20250525     402  37.55556  127.14498  0.387759
# 317854    42804  20250525     413  37.53344  127.08601  0.434471
# 317855    42804  20250525     569  37.58224  127.15698  0.481182
#
#         Sum_rainfall  Max_rainfall_1H  Max_rainfall_1H_occur_time  \
# 2355          -0.563         -0.53376                         0.0
# ...

# %%
df = df[df['YMD'] != df['YMD'].max()]
df
# Out:
#         Spot_id       YMD  STN_ID       LAT        LON    target  \
# 0          6001  20230401     408  37.58463  127.06036  0.640000
# 1          6001  20230401     414  37.61172  126.99944  0.527893
# 2          6001  20230401     424  37.63801  127.00981  0.574605
# 3          6001  20230402     408  37.58463  127.06036  0.574605
# 4          6001  20230402     414  37.61172  126.99944  0.443813
# ...         ...       ...     ...       ...        ...       ...
# 317848    42804  20250523     413  37.53344  127.08601  0.331706
# 317849    42804  20250523     569  37.58224  127.15698  0.228941
# 317850    42804  20250524     402  37.55556  127.14498 -0.154092
# 317851    42804  20250524     413  37.53344  127.08601 -0.032643
# 317852    42804  20250524     569  37.58224  127.15698 -0.060669
#
#         Sum_rainfall  Max_rainfall_1H  Max_rainfall_1H_occur_time  \
# 0          -0.563000        -0.533760                         0.0
# ...
